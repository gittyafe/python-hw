# %% [markdown]
# # תרגול אמצע

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in C:\Python312\Lib\site-packages (2.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
random_arr = np.random.randint(1, 50, size=(10))
random_arr
# Out:
# array([38, 40, 27, 25, 40, 20, 33, 20, 10,  8], dtype=int32)

# %%
random_arr.size
# Out:
# 10

# %%
np.ndim(random_arr)
# Out:
# 1

# %%
random_arr.dtype
# Out:
# dtype('int32')

# %%
random_arr = np.random.randint(10, 100, size=(2,5))
random_arr
# Out:
# array([[81, 11, 37, 51, 86],
#        [62, 38, 29, 25, 80]], dtype=int32)

# %% [markdown]
# # שיעורי בית

# %%
random_arr = np.random.randint(1, 50, size=(10))
np.mean(random_arr)
# Out:
# np.float64(16.9)

# %%
arr1 = np.array([[1,2],[3,4],[5,6]])
arr2 = np.array([[1,2],[3,4],[5,6]])
arr3 = np.add(arr1, arr2)
np.mean(arr3)
# Out:
# np.float64(7.0)

# %%
arr = np.random.randint(1, 100, size=(20))
condition = arr > 50
filtered_arr = arr[condition]
filtered_arr
# Out:
# array([76, 79, 93, 89, 66, 98, 92], dtype=int32)

# %%
arr = np.arange(1, 11)
np.random.shuffle(arr)
np.random.choice(arr, size=3, replace=False)
# Out:
# array([2, 4, 3])
